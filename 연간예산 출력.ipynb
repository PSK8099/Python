# %%
import pandas as pd

def process_cost_center_data(input_file, output_file):
    # 엑셀 파일 읽기
    data = pd.read_excel(input_file)

    # 열 이름 정의
    data.columns = ["코스트센터/비용항목", "연간예산(A)", "배정예산(B)", "약정금액(C)", "집행금액(D)"]

    # 계산 열 추가
    data["배정예산 대비 집행률(D/B)"] = data["집행금액(D)"] / data["배정예산(B)"] * 100
    data["연간예산 대비 집행률(D/A)"] = data["집행금액(D)"] / data["연간예산(A)"] * 100

    # 코스트센터와 비용항목 구분
    data["코스트센터"] = data["코스트센터/비용항목"].where(data["코스트센터/비용항목"].str.len() == 7)
    data["비용항목"] = data["코스트센터/비용항목"].where(data["코스트센터/비용항목"].str.len() == 6)
    data["코스트센터"] = data["코스트센터"].fillna(method="ffill")

    # 결과 저장용 ExcelWriter 생성
    with pd.ExcelWriter(output_file, engine="openpyxl") as writer:
        # 코스트센터별 시트 생성
        for cost_center, group in data.groupby("코스트센터"):
            group.drop(columns="코스트센터", inplace=True)
            group.to_excel(writer, sheet_name=str(cost_center), index=False)

        # 요약 시트 생성
        summary = data.groupby("코스트센터").agg({
            "연간예산(A)": "sum",
            "배정예산(B)": "sum",
            "약정금액(C)": "sum",
            "집행금액(D)": "sum"
        })
        summary["배정예산 대비 집행률(D/B)"] = summary["집행금액(D)"] / summary["배정예산(B)"] * 100
        summary["연간예산 대비 집행률(D/A)"] = summary["집행금액(D)"] / summary["연간예산(A)"] * 100
        summary.to_excel(writer, sheet_name="요약", index=True)

# 실행 예제
input_file = "Original cost.xlsx"  # 입력 파일 이름
output_file = "processed_cost_center.xlsx"  # 출력 파일 이름
process_cost_center_data(input_file, output_file)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 40
#      38 input_file = "Original cost.xlsx"  # 입력 파일 이름
#      39 output_file = "processed_cost_center.xlsx"  # 출력 파일 이름
# ---> 40 process_cost_center_data(input_file, output_file)
#
# Cell In[1], line 8, in process_cost_center_data(input_file, output_file)
#       5 data = pd.read_excel(input_file)
#       7 # 열 이름 정의
# ----> 8 data.columns = ["코스트센터/비용항목", "연간예산(A)", "배정예산(B)", "약정금액(C)", "집행금액(D)"]
#      10 # 계산 열 추가
#      11 data["배정예산 대비 집행률(D/B)"] = data["집행금액(D)"] / data["배정예산(B)"] * 100
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6218, in NDFrame.__setattr__(self, name, value)
#    6216 try:
#    6217     object.__getattribute__(self, name)
# -> 6218     return object.__setattr__(self, name, value)
#    6219 except AttributeError:
#    6220     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:767, in NDFrame._set_axis(self, axis, labels)
#     762 """
#     763 This is called from the cython code when we set the `index` attribute
#     764 directly, e.g. `series.index = [1, 2, 3]`.
#     765 """
#     766 labels = ensure_index(labels)
# --> 767 self._mgr.set_axis(axis, labels)
#     768 self._clear_item_cache()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:227, in BaseBlockManager.set_axis(self, axis, new_labels)
#     225 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     226     # Caller is responsible for ensuring we have an Index object.
# --> 227     self._validate_set_axis(axis, new_labels)
#     228     self.axes[axis] = new_labels
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\base.py:85, in DataManager._validate_set_axis(self, axis, new_labels)
#      82     pass
#      84 elif new_len != old_len:
# ---> 85     raise ValueError(
#      86         f"Length mismatch: Expected axis has {old_len} elements, new "
#      87         f"values have {new_len} elements"
#      88     )
#
# ValueError: Length mismatch: Expected axis has 7 elements, new values have 5 elements

# %%
import pandas as pd

def process_cost_center_data(input_file, output_file):
    # 엑셀 파일 읽기
    data = pd.read_excel(input_file, header=0)  # 첫 번째 행을 헤더로 읽기

    # 데이터 구조 확인 및 열 이름 출력
    print("파일에서 읽은 열 이름:", data.columns.tolist())

    # 열 이름 정의
    # 필요에 따라 파일에서 읽은 열 이름에 맞게 조정
    data.columns = [
        "코스트센터/비용항목", 
        "연간예산(A)", 
        "배정예산(B)", 
        "약정금액(C)", 
        "집행금액(D)",
        "기타1",  # 추가 열이 있을 경우 이름 지정
        "기타2"   # 추가 열이 있을 경우 이름 지정
    ][:len(data.columns)]  # 읽은 열 개수에 맞게 자르기

    # 계산 열 추가
    data["배정예산 대비 집행률(D/B)"] = data["집행금액(D)"] / data["배정예산(B)"] * 100
    data["연간예산 대비 집행률(D/A)"] = data["집행금액(D)"] / data["연간예산(A)"] * 100

    # 코스트센터와 비용항목 구분
    data["코스트센터"] = data["코스트센터/비용항목"].where(data["코스트센터/비용항목"].str.len() == 7)
    data["비용항목"] = data["코스트센터/비용항목"].where(data["코스트센터/비용항목"].str.len() == 6)
    data["코스트센터"] = data["코스트센터"].fillna(method="ffill")

    # 결과 저장용 ExcelWriter 생성
    with pd.ExcelWriter(output_file, engine="openpyxl") as writer:
        # 코스트센터별 시트 생성
        for cost_center, group in data.groupby("코스트센터"):
            group.drop(columns="코스트센터", inplace=True)
            group.to_excel(writer, sheet_name=str(cost_center), index=False)

        # 요약 시트 생성
        summary = data.groupby("코스트센터").agg({
            "연간예산(A)": "sum",
            "배정예산(B)": "sum",
            "약정금액(C)": "sum",
            "집행금액(D)": "sum"
        })
        summary["배정예산 대비 집행률(D/B)"] = summary["집행금액(D)"] / summary["배정예산(B)"] * 100
        summary["연간예산 대비 집행률(D/A)"] = summary["집행금액(D)"] / summary["연간예산(A)"] * 100
        summary.to_excel(writer, sheet_name="요약", index=True)

# 실행 예제
input_file = "Original cost.xlsx"  # 입력 파일 이름
output_file = "processed_cost_center.xlsx"  # 출력 파일 이름
process_cost_center_data(input_file, output_file)
# Out:
# 파일에서 읽은 열 이름: ['구분', '연간예산(A)', '배정예산(B)', '약정(C)', '집행(D)', 'D/B(%)', 'D/A(%)']
# C:\Users\Dev\AppData\Local\Temp\ipykernel_34384\676153673.py:29: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data["코스트센터"] = data["코스트센터"].fillna(method="ffill")

# %%
import pandas as pd

def process_cost_center_data(input_file, output_file):
    # 엑셀 파일 읽기
    data = pd.read_excel(input_file, header=0)  # 첫 번째 행을 헤더로 읽기

    # 데이터 구조 확인 및 열 이름 출력
    print("파일에서 읽은 열 이름:", data.columns.tolist())

    # 열 이름 정의
    # 필요에 따라 파일에서 읽은 열 이름에 맞게 조정
    data.columns = [
        "코스트센터/비용항목", 
        "연간예산(A)", 
        "배정예산(B)", 
        "약정금액(C)", 
        "집행금액(D)",
        "기타1",  # 추가 열이 있을 경우 이름 지정
        "기타2"   # 추가 열이 있을 경우 이름 지정
    ][:len(data.columns)]  # 읽은 열 개수에 맞게 자르기

    # 계산 열 추가
    data["배정예산 대비 집행률(D/B)"] = data["집행금액(D)"] / data["배정예산(B)"] * 100
    data["연간예산 대비 집행률(D/A)"] = data["집행금액(D)"] / data["연간예산(A)"] * 100

    # 코스트센터와 비용항목 구분
    data["코스트센터"] = data["코스트센터/비용항목"].where(data["코스트센터/비용항목"].str.len() == 7)
    data["비용항목"] = data["코스트센터/비용항목"].where(data["코스트센터/비용항목"].str.len() == 6)
    data["코스트센터"] = data["코스트센터"].ffill()

    # 결과 저장용 ExcelWriter 생성
    with pd.ExcelWriter(output_file, engine="openpyxl") as writer:
        # 코스트센터별 시트 생성
        for cost_center, group in data.groupby("코스트센터"):
            group.drop(columns="코스트센터", inplace=True)
            group.to_excel(writer, sheet_name=str(cost_center), index=False)

        # 요약 시트 생성
        summary = data.groupby("코스트센터").agg({
            "연간예산(A)": "sum",
            "배정예산(B)": "sum",
            "약정금액(C)": "sum",
            "집행금액(D)": "sum"
        })
        summary["배정예산 대비 집행률(D/B)"] = summary["집행금액(D)"] / summary["배정예산(B)"] * 100
        summary["연간예산 대비 집행률(D/A)"] = summary["집행금액(D)"] / summary["연간예산(A)"] * 100
        summary.to_excel(writer, sheet_name="요약", index=True)

# 실행 예제
input_file = "Original cost.xlsx"  # 입력 파일 이름
output_file = "processed_cost_center.xlsx"  # 출력 파일 이름
process_cost_center_data(input_file, output_file)
# Out:
# 파일에서 읽은 열 이름: ['구분', '연간예산(A)', '배정예산(B)', '약정(C)', '집행(D)', 'D/B(%)', 'D/A(%)']

# %%
import pandas as pd

def process_cost_center_data(input_file, output_file):
    # 엑셀 파일 읽기
    data = pd.read_excel(input_file, header=0)  # 첫 번째 행을 헤더로 읽기

    # 데이터 구조 확인 및 열 이름 출력
    print("파일에서 읽은 열 이름:", data.columns.tolist())

    # 열 이름 정의
    # 필요에 따라 파일에서 읽은 열 이름에 맞게 조정
    data.columns = [
        "코스트센터/비용항목", 
        "연간예산(A)", 
        "배정예산(B)", 
        "약정금액(C)", 
        "집행금액(D)"
    ][:len(data.columns)]  # 읽은 열 개수에 맞게 자르기

    # 데이터 비어 있는 행 제거
    data.dropna(subset=["코스트센터/비용항목", "연간예산(A)", "배정예산(B)", "약정금액(C)", "집행금액(D)"], inplace=True)

    # 계산 열 추가
    data["배정예산 대비 집행률(D/B)"] = data["집행금액(D)"] / data["배정예산(B)"] * 100
    data["연간예산 대비 집행률(D/A)"] = data["집행금액(D)"] / data["연간예산(A)"] * 100

    # 코스트센터와 비용항목 구분
    data["코스트센터"] = data["코스트센터/비용항목"].where(data["코스트센터/비용항목"].str.len() == 7)
    data["비용항목"] = data["코스트센터/비용항목"].where(data["코스트센터/비용항목"].str.len() == 6)
    data["코스트센터"] = data["코스트센터"].ffill()

    # 결과 저장용 ExcelWriter 생성
    with pd.ExcelWriter(output_file, engine="openpyxl") as writer:
        # 코스트센터별 시트 생성
        for cost_center, group in data.groupby("코스트센터"):
            group.drop(columns="코스트센터", inplace=True)
            group.to_excel(writer, sheet_name=str(cost_center), index=False)

        # 요약 시트 생성
        summary = data.groupby("코스트센터").agg({
            "연간예산(A)": "sum",
            "배정예산(B)": "sum",
            "약정금액(C)": "sum",
            "집행금액(D)": "sum"
        })
        summary["배정예산 대비 집행률(D/B)"] = summary["집행금액(D)"] / summary["배정예산(B)"] * 100
        summary["연간예산 대비 집행률(D/A)"] = summary["집행금액(D)"] / summary["연간예산(A)"] * 100
        summary.to_excel(writer, sheet_name="요약", index=True)

# 실행 예제
input_file = "Original cost.xlsx"  # 입력 파일 이름
output_file = "processed_cost_center.xlsx"  # 출력 파일 이름
process_cost_center_data(input_file, output_file)
# Out:
# 파일에서 읽은 열 이름: ['구분', '연간예산(A)', '배정예산(B)', '약정(C)', '집행(D)', 'D/B(%)', 'D/A(%)']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 53
#      51 input_file = "Original cost.xlsx"  # 입력 파일 이름
#      52 output_file = "processed_cost_center.xlsx"  # 출력 파일 이름
# ---> 53 process_cost_center_data(input_file, output_file)
#
# Cell In[4], line 12, in process_cost_center_data(input_file, output_file)
#       8 print("파일에서 읽은 열 이름:", data.columns.tolist())
#      10 # 열 이름 정의
#      11 # 필요에 따라 파일에서 읽은 열 이름에 맞게 조정
# ---> 12 data.columns = [
#      13     "코스트센터/비용항목",
#      14     "연간예산(A)",
#      15     "배정예산(B)",
#      16     "약정금액(C)",
#      17     "집행금액(D)"
#      18 ][:len(data.columns)]  # 읽은 열 개수에 맞게 자르기
#      20 # 데이터 비어 있는 행 제거
#      21 data.dropna(subset=["코스트센터/비용항목", "연간예산(A)", "배정예산(B)", "약정금액(C)", "집행금액(D)"], inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6218, in NDFrame.__setattr__(self, name, value)
#    6216 try:
#    6217     object.__getattribute__(self, name)
# -> 6218     return object.__setattr__(self, name, value)
#    6219 except AttributeError:
#    6220     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:767, in NDFrame._set_axis(self, axis, labels)
#     762 """
#     763 This is called from the cython code when we set the `index` attribute
#     764 directly, e.g. `series.index = [1, 2, 3]`.
#     765 """
#     766 labels = ensure_index(labels)
# --> 767 self._mgr.set_axis(axis, labels)
#     768 self._clear_item_cache()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:227, in BaseBlockManager.set_axis(self, axis, new_labels)
#     225 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     226     # Caller is responsible for ensuring we have an Index object.
# --> 227     self._validate_set_axis(axis, new_labels)
#     228     self.axes[axis] = new_labels
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\base.py:85, in DataManager._validate_set_axis(self, axis, new_labels)
#      82     pass
#      84 elif new_len != old_len:
# ---> 85     raise ValueError(
#      86         f"Length mismatch: Expected axis has {old_len} elements, new "
#      87         f"values have {new_len} elements"
#      88     )
#
# ValueError: Length mismatch: Expected axis has 7 elements, new values have 5 elements

# %%
import pandas as pd

def process_cost_center_data(input_file, output_file):
    # 엑셀 파일 읽기
    data = pd.read_excel(input_file, header=0)  # 첫 번째 행을 헤더로 읽기

    # 데이터 구조 확인 및 열 이름 출력
    print("파일에서 읽은 열 이름:", data.columns.tolist())

    # 데이터 열 개수에 맞게 열 이름 정의
    expected_columns = [
        "코스트센터", 
        "연간예산(A)", 
        "배정예산(B)", 
        "약정금액(C)", 
        "집행금액(D)"
    ]
    data.columns = expected_columns[:len(data.columns)]  # 읽은 열 개수에 맞게 자르기

    # 데이터 비어 있는 행 제거
    data.dropna(subset=[col for col in data.columns if col in expected_columns], inplace=True)

    # 계산 열 추가
    data["배정예산 대비 집행률(D/B)"] = data["집행금액(D)"] / data["배정예산(B)"] * 100
    data["연간예산 대비 집행률(D/A)"] = data["집행금액(D)"] / data["연간예산(A)"] * 100

    # 코스트센터와 비용항목 구분
    data["코스트센터"] = data["코스트센터"].where(data["코스트센터"].str.len() == 7)
    data["비용항목"] = data["비용항목"].where(data["비용항목"].str.len() == 6)
    data["코스트센터"] = data["코스트센터"].ffill()

    # 결과 저장용 ExcelWriter 생성
    with pd.ExcelWriter(output_file, engine="openpyxl") as writer:
        # 코스트센터별 시트 생성
        for cost_center, group in data.groupby("코스트센터"):
            group.drop(columns="코스트센터", inplace=True)
            group.to_excel(writer, sheet_name=str(cost_center), index=False)

        # 요약 시트 생성
        summary = data.groupby("코스트센터").agg({
            "연간예산(A)": "sum",
            "배정예산(B)": "sum",
            "약정금액(C)": "sum",
            "집행금액(D)": "sum"
        })
        summary["배정예산 대비 집행률(D/B)"] = summary["집행금액(D)"] / summary["배정예산(B)"] * 100
        summary["연간예산 대비 집행률(D/A)"] = summary["집행금액(D)"] / summary["연간예산(A)"] * 100
        summary.to_excel(writer, sheet_name="요약", index=True)

# 실행 예제
input_file = "Original cost.xlsx"  # 입력 파일 이름
output_file = "processed_cost_center.xlsx"  # 출력 파일 이름
process_cost_center_data(input_file, output_file)
# Out:
# 파일에서 읽은 열 이름: ['구분', '연간예산(A)', '배정예산(B)', '약정(C)', '집행(D)', 'D/B(%)', 'D/A(%)']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 53
#      51 input_file = "Original cost.xlsx"  # 입력 파일 이름
#      52 output_file = "processed_cost_center.xlsx"  # 출력 파일 이름
# ---> 53 process_cost_center_data(input_file, output_file)
#
# Cell In[5], line 18, in process_cost_center_data(input_file, output_file)
#      10 # 데이터 열 개수에 맞게 열 이름 정의
#      11 expected_columns = [
#      12     "코스트센터",
#      13     "연간예산(A)",
#    (...)
#      16     "집행금액(D)"
#      17 ]
# ---> 18 data.columns = expected_columns[:len(data.columns)]  # 읽은 열 개수에 맞게 자르기
#      20 # 데이터 비어 있는 행 제거
#      21 data.dropna(subset=[col for col in data.columns if col in expected_columns], inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6218, in NDFrame.__setattr__(self, name, value)
#    6216 try:
#    6217     object.__getattribute__(self, name)
# -> 6218     return object.__setattr__(self, name, value)
#    6219 except AttributeError:
#    6220     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:767, in NDFrame._set_axis(self, axis, labels)
#     762 """
#     763 This is called from the cython code when we set the `index` attribute
#     764 directly, e.g. `series.index = [1, 2, 3]`.
#     765 """
#     766 labels = ensure_index(labels)
# --> 767 self._mgr.set_axis(axis, labels)
#     768 self._clear_item_cache()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:227, in BaseBlockManager.set_axis(self, axis, new_labels)
#     225 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     226     # Caller is responsible for ensuring we have an Index object.
# --> 227     self._validate_set_axis(axis, new_labels)
#     228     self.axes[axis] = new_labels
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\base.py:85, in DataManager._validate_set_axis(self, axis, new_labels)
#      82     pass
#      84 elif new_len != old_len:
# ---> 85     raise ValueError(
#      86         f"Length mismatch: Expected axis has {old_len} elements, new "
#      87         f"values have {new_len} elements"
#      88     )
#
# ValueError: Length mismatch: Expected axis has 7 elements, new values have 5 elements

# %%
import pandas as pd

def process_cost_center_data(input_file, output_file):
    # 엑셀 파일 읽기
    data = pd.read_excel(input_file, header=0)  # 첫 번째 행을 헤더로 읽기

    # 열 이름 정의
    data.columns = [
        "코스트센터/비용항목", 
        "연간예산(A)", 
        "배정예산(B)", 
        "약정금액(C)", 
        "집행금액(D)"
    ]

    # 계산 열 추가
    data["배정예산 대비 집행률(D/B)"] = (data["집행금액(D)"] / data["배정예산(B)"] * 100).fillna(0)
    data["연간예산 대비 집행률(D/A)"] = (data["집행금액(D)"] / data["연간예산(A)"] * 100).fillna(0)

    # 코스트센터와 비용항목 구분
    data["코스트센터"] = data["코스트센터/비용항목"].str.extract(r'(\d{7})')
    data["비용항목"] = data["코스트센터/비용항목"].str.extract(r'(\d{6})')
    data["코스트센터"] = data["코스트센터"].fillna(method="ffill")

    # 결과 저장용 ExcelWriter 생성
    with pd.ExcelWriter(output_file, engine="openpyxl") as writer:
        # 요약 시트 생성
        summary = data.groupby("코스트센터").agg({
            "연간예산(A)": "sum",
            "배정예산(B)": "sum",
            "약정금액(C)": "sum",
            "집행금액(D)": "sum"
        })
        summary["배정예산 대비 집행률(D/B)"] = (summary["집행금액(D)"] / summary["배정예산(B)"] * 100).fillna(0)
        summary["연간예산 대비 집행률(D/A)"] = (summary["집행금액(D)"] / summary["연간예산(A)"] * 100).fillna(0)
        summary.to_excel(writer, sheet_name="요약", index=True)

        # 코스트센터별 시트 생성
        for cost_center, group in data.groupby("코스트센터"):
            group.drop(columns="코스트센터", inplace=True)
            group.to_excel(writer, sheet_name=str(cost_center), index=False)

# 실행 예제
input_file = "Original cost.xlsx"  # 입력 파일 이름
output_file = "processed_cost_center.xlsx"  # 출력 파일 이름
process_cost_center_data(input_file, output_file)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 46
#      44 input_file = "Original cost.xlsx"  # 입력 파일 이름
#      45 output_file = "processed_cost_center.xlsx"  # 출력 파일 이름
# ---> 46 process_cost_center_data(input_file, output_file)
#
# Cell In[6], line 8, in process_cost_center_data(input_file, output_file)
#       5 data = pd.read_excel(input_file, header=0)  # 첫 번째 행을 헤더로 읽기
#       7 # 열 이름 정의
# ----> 8 data.columns = [
#       9     "코스트센터/비용항목",
#      10     "연간예산(A)",
#      11     "배정예산(B)",
#      12     "약정금액(C)",
#      13     "집행금액(D)"
#      14 ]
#      16 # 계산 열 추가
#      17 data["배정예산 대비 집행률(D/B)"] = (data["집행금액(D)"] / data["배정예산(B)"] * 100).fillna(0)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6218, in NDFrame.__setattr__(self, name, value)
#    6216 try:
#    6217     object.__getattribute__(self, name)
# -> 6218     return object.__setattr__(self, name, value)
#    6219 except AttributeError:
#    6220     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:767, in NDFrame._set_axis(self, axis, labels)
#     762 """
#     763 This is called from the cython code when we set the `index` attribute
#     764 directly, e.g. `series.index = [1, 2, 3]`.
#     765 """
#     766 labels = ensure_index(labels)
# --> 767 self._mgr.set_axis(axis, labels)
#     768 self._clear_item_cache()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:227, in BaseBlockManager.set_axis(self, axis, new_labels)
#     225 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     226     # Caller is responsible for ensuring we have an Index object.
# --> 227     self._validate_set_axis(axis, new_labels)
#     228     self.axes[axis] = new_labels
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\base.py:85, in DataManager._validate_set_axis(self, axis, new_labels)
#      82     pass
#      84 elif new_len != old_len:
# ---> 85     raise ValueError(
#      86         f"Length mismatch: Expected axis has {old_len} elements, new "
#      87         f"values have {new_len} elements"
#      88     )
#
# ValueError: Length mismatch: Expected axis has 7 elements, new values have 5 elements

# %%
import pandas as pd

def process_cost_center_data(input_file, output_file):
    # 엑셀 파일 읽기
    data = pd.read_excel(input_file, header=0)  # 첫 번째 행을 헤더로 읽기

    # 열 이름 재정의
    data.columns = [
        "구분", 
        "연간예산(A)", 
        "배정예산(B)", 
        "약정(C)", 
        "집행(D)", 
        "D/B(%)", 
        "D/A(%)"
    ]

    # 코스트센터와 비용항목 구분
    data["코스트센터"] = data["구분"].str.extract(r'(\d{7})')
    data["비용항목"] = data["구분"].str.extract(r'(\d{6})')
    data["코스트센터"] = data["코스트센터"].ffill()

    # 코스트센터별 데이터 그룹화
    with pd.ExcelWriter(output_file, engine="openpyxl") as writer:
        # 요약 시트 생성
        summary = data.groupby("코스트센터").agg({
            "연간예산(A)": "sum",
            "배정예산(B)": "sum",
            "약정(C)": "sum",
            "집행(D)": "sum"
        })
        summary["D/B(%)"] = (summary["집행(D)"] / summary["배정예산(B)"] * 100).fillna(0)
        summary["D/A(%)"] = (summary["집행(D)"] / summary["연간예산(A)"] * 100).fillna(0)
        summary.to_excel(writer, sheet_name="요약", index=True)

        # 코스트센터별 시트 생성
        for cost_center, group in data.groupby("코스트센터"):
            group.drop(columns="코스트센터", inplace=True)
            group.to_excel(writer, sheet_name=str(cost_center), index=False)

# 실행 예제
input_file = "Original cost.xlsx"  # 입력 파일 이름
output_file = "processed_cost_center.xlsx"  # 출력 파일 이름
process_cost_center_data(input_file, output_file)
